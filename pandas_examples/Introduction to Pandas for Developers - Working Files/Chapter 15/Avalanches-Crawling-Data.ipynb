# %%
from bs4 import BeautifulSoup
import pandas as pd
import requests as r

# %%
base = 'https://utahavalanchecenter.org/'
url = base + 'avalanches/fatalities'

headers = {}

def get_avalanches(url):
    req = r.get(url, headers=headers)
    data = req.text
    
    soup = BeautifulSoup(data)
    content = soup.find(id='content')
    trs = content.find_all('tr')
    res = []
    for tr in trs:
        tds = tr.find_all('td')
        data = {}
        for td in tds:
            name, value = get_field_name_value(td)
            if not name:
                continue
            data[name] = value
        if data:
            res.append(data)
    return res

def get_field_name_value(elem):
    tags = elem.get('class')
    start = 'views-field-field-'
    for t in tags:
        if t.startswith(start):
            return t[len(start):], ''.join(elem.stripped_strings)
        elif t == 'views-field-view-node':
            return 'url', elem.a['href']
    return None, None

# %%
get_avalanches(url)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/matt/.pycast-env/lib/python3.4/site-packages/requests/packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, **httplib_request_kw)
#     375             try:  # Python 2.7, use buffering of HTTP responses
# --> 376                 httplib_response = conn.getresponse(buffering=True)
#     377             except TypeError:  # Python 2.6 and older
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# BadStatusLine                             Traceback (most recent call last)
# /Users/matt/.pycast-env/lib/python3.4/site-packages/requests/packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, **response_kw)
#     558                                                   timeout=timeout_obj,
# --> 559                                                   body=body, headers=headers)
#     560
#
# /Users/matt/.pycast-env/lib/python3.4/site-packages/requests/packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, **httplib_request_kw)
#     377             except TypeError:  # Python 2.6 and older
# --> 378                 httplib_response = conn.getresponse()
#     379         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# /usr/local/Cellar/python3/3.4.3/Frameworks/Python.framework/Versions/3.4/lib/python3.4/http/client.py in getresponse(self)
#    1170         try:
# -> 1171             response.begin()
#    1172             assert response.will_close != _UNKNOWN
#
# /usr/local/Cellar/python3/3.4.3/Frameworks/Python.framework/Versions/3.4/lib/python3.4/http/client.py in begin(self)
#     350         while True:
# --> 351             version, status, reason = self._read_status()
#     352             if status != CONTINUE:
#
# /usr/local/Cellar/python3/3.4.3/Frameworks/Python.framework/Versions/3.4/lib/python3.4/http/client.py in _read_status(self)
#     320             # sending a valid response.
# --> 321             raise BadStatusLine(line)
#     322         try:
#
# BadStatusLine: ''
#
# During handling of the above exception, another exception occurred:
#
# ProtocolError                             Traceback (most recent call last)
# /Users/matt/.pycast-env/lib/python3.4/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     369                     retries=self.max_retries,
# --> 370                     timeout=timeout
#     371                 )
#
# /Users/matt/.pycast-env/lib/python3.4/site-packages/requests/packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, **response_kw)
#     608             retries = retries.increment(method, url, error=e, _pool=self,
# --> 609                                         _stacktrace=sys.exc_info()[2])
#     610             retries.sleep()
#
# /Users/matt/.pycast-env/lib/python3.4/site-packages/requests/packages/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     244             if read is False:
# --> 245                 raise six.reraise(type(error), error, _stacktrace)
#     246             elif read is not None:
#
# /Users/matt/.pycast-env/lib/python3.4/site-packages/requests/packages/urllib3/packages/six.py in reraise(tp, value, tb)
#     308         if value.__traceback__ is not tb:
# --> 309             raise value.with_traceback(tb)
#     310         raise value
#
# /Users/matt/.pycast-env/lib/python3.4/site-packages/requests/packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, **response_kw)
#     558                                                   timeout=timeout_obj,
# --> 559                                                   body=body, headers=headers)
#     560
#
# /Users/matt/.pycast-env/lib/python3.4/site-packages/requests/packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, **httplib_request_kw)
#     377             except TypeError:  # Python 2.6 and older
# --> 378                 httplib_response = conn.getresponse()
#     379         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# /usr/local/Cellar/python3/3.4.3/Frameworks/Python.framework/Versions/3.4/lib/python3.4/http/client.py in getresponse(self)
#    1170         try:
# -> 1171             response.begin()
#    1172             assert response.will_close != _UNKNOWN
#
# /usr/local/Cellar/python3/3.4.3/Frameworks/Python.framework/Versions/3.4/lib/python3.4/http/client.py in begin(self)
#     350         while True:
# --> 351             version, status, reason = self._read_status()
#     352             if status != CONTINUE:
#
# /usr/local/Cellar/python3/3.4.3/Frameworks/Python.framework/Versions/3.4/lib/python3.4/http/client.py in _read_status(self)
#     320             # sending a valid response.
# --> 321             raise BadStatusLine(line)
#     322         try:
#
# ProtocolError: ('Connection aborted.', BadStatusLine("''",))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-4-a2abbdab1d63> in <module>()
# ----> 1 get_avalanches(url)
#
# <ipython-input-3-0911cdcd389e> in get_avalanches(url)
#       5
#       6 def get_avalanches(url):
# ----> 7     req = r.get(url, headers=headers)
#       8     data = req.text
#       9
#
# /Users/matt/.pycast-env/lib/python3.4/site-packages/requests/api.py in get(url, params, **kwargs)
#      67
#      68     kwargs.setdefault('allow_redirects', True)
# ---> 69     return request('get', url, params=params, **kwargs)
#      70
#      71
#
# /Users/matt/.pycast-env/lib/python3.4/site-packages/requests/api.py in request(method, url, **kwargs)
#      48
#      49     session = sessions.Session()
# ---> 50     response = session.request(method=method, url=url, **kwargs)
#      51     # By explicitly closing the session, we avoid leaving sockets open which
#      52     # can trigger a ResourceWarning in some cases, and look like a memory leak
#
# /Users/matt/.pycast-env/lib/python3.4/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     466         }
#     467         send_kwargs.update(settings)
# --> 468         resp = self.send(prep, **send_kwargs)
#     469
#     470         return resp
#
# /Users/matt/.pycast-env/lib/python3.4/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     574
#     575         # Send the request
# --> 576         r = adapter.send(request, **kwargs)
#     577
#     578         # Total elapsed time of the request (approximately)
#
# /Users/matt/.pycast-env/lib/python3.4/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     410
#     411         except (ProtocolError, socket.error) as err:
# --> 412             raise ConnectionError(err, request=request)
#     413
#     414         except MaxRetryError as e:
#
# ConnectionError: ('Connection aborted.', BadStatusLine("''",))

# %%
headers = {'User-Agent': 'Mozilla/5.0'}
avs = get_avalanches(url)
# Out:
# /Users/matt/.pycast-env/lib/python3.4/site-packages/bs4/__init__.py:166: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("html.parser"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# To get rid of this warning, change this:
#
#  BeautifulSoup([your markup])
#
# to this:
#
#  BeautifulSoup([your markup], "html.parser")
#
#   markup_type=markup_type))

# %%
pd.DataFrame(avs)
# Out:
#                            coordinates killed occurrence-date  \
# 0   41.215552643517, -111.873779284110      1       03/4/2015
# 1   40.812120000000, -110.906296000000      1       03/7/2014
# 2   39.585986000000, -111.270003000000      1       02/9/2014
# 3   40.482366000000, -111.648088000000      1       02/8/2014
# 4   40.629000000000, -111.666412000000      1      04/11/2013
# 5   39.043600000000, -111.519000000000      1       03/1/2013
# 6                                           2      01/18/2013
# 7   38.539320000000, -109.209852000000      1       03/3/2012
# 8   40.653034000000, -111.592255000000      1      02/23/2012
# 9   38.716456000000, -111.721988000000      1       02/5/2012
# 10  40.624442000000, -111.669588000000      1      01/28/2012
# 11  40.568491000000, -111.652937000000      1      11/13/2011
# 12  39.372824000000, -111.422482000000      1      03/26/2011
# 13  40.847320000000, -111.015129000000      1      11/26/2010
# 14  41.050424000000, -111.844082000000      1       04/4/2010
# 15  40.856199868806, -111.754991041400      1      01/29/2010
# 16  40.617112000000, -111.623840000000      1      01/27/2010
# 17  41.215563000000, -111.873307000000      1      01/24/2010
# 18  40.871988000000, -110.974016000000      1      12/30/2008
# 19  41.711752000000, -111.717181000000      2      12/24/2008
# 20  40.569632000000, -111.641693000000      1      12/14/2008
# 21      0.000000000000, 0.000000000000      1      12/31/2007
# 22  40.834820000000, -111.008220000000      1      12/25/2007
# 23  40.660164000000, -111.596117000000      1      12/23/2007
# 24  40.666707000000, -111.683493000000      1      02/21/2007
# 25  41.211302000000, -111.878414000000      1      02/18/2007
# 26  40.393071000000, -111.140785000000      1      02/17/2007
# 27  38.628762622838, -112.023038851360      1      02/17/2007
# 28  40.581465000000, -111.584144000000      1       04/3/2006
# 29  41.204845000000, -111.888671000000      1      03/11/2006
# ..                                 ...    ...             ...
# 66  40.585286000000, -111.605041000000      1       04/3/1993
# 67                                          1      02/25/1993
# 68  40.372185694061, -111.585446285570      1      01/16/1993
# 69  40.551518000000, -111.649544000000      1       04/1/1992
# 70                                          4      02/12/1992
# 71                                          1      11/25/1989
# 72  40.591841000000, -111.604827000000      1      02/15/1987
# 73                                          1      11/20/1986
# 74  40.566950000000, -111.624353000000      1      02/19/1986
# 75  40.606262000000, -111.576839000000      1      02/17/1986
# 76  40.285983000000, -111.506379000000      1       01/6/1986
# 77  40.577629000000, -111.594312000000      2      11/13/1985
# 78  40.641857000000, -111.520412000000      1      03/19/1985
# 79  41.362519000000, -111.782882000000      1      02/22/1985
# 80  40.593007000000, -111.659243000000      1       01/2/1984
# 81  40.694668000000, -111.604312000000      1      03/22/1982
# 82  40.664995000000, -111.693146000000      1       03/1/1981
# 83  40.631609000000, -111.654308000000      1       02/1/1981
# 84  40.606529000000, -111.594484000000      1      01/11/1980
# 85  40.656105000000, -111.602252000000      1       04/2/1979
# 86  39.702192039624, -110.949728952290      1      01/19/1979
# 87  40.564342704045, -111.652085678840      1       03/3/1977
# 88  40.586506674316, -111.626428069460      1       01/6/1976
# 89                                          1      12/29/1973
# 90  40.572657369383, -111.651414858090      1      01/20/1970
# 91  40.226133346151, -111.614400373680      1      02/19/1968
# 92  40.708361000000, -111.759796000000      2      02/12/1967
# 93  40.631302096436, -111.516682134840      1      12/31/1965
# 94  41.204951129311, -111.900259481650      1      03/29/1964
# 95  41.205508551921, -111.875901000480      1       03/9/1958
#
#    region-forecaster     region-forecaster-1      trigger  \
# 0              Ogden            Hells Canyon  Snowboarder
# 1             Uintas               Gold Hill  Snowmobiler
# 2            Skyline    Huntington Reservior  Snowmobiler
# 3              Provo             Tibble Fork    Snowshoer
# 4          Salt Lake           Kessler Slabs        Skier
# 5            Skyline          White Mountain  Snowmobiler
# 6             Uintas   West Fork of Duchesne  Snowmobiler
# 7               Moab            Beaver Basin  Snowmobiler
# 8          Salt Lake              Dutch Draw  Snowboarder
# 9            Skyline    Lost Creek Reservoir  Snowmobiler
# 10         Salt Lake            Kessler Peak  Snowboarder
# 11         Salt Lake              Gad Valley  Snowboarder
# 12           Skyline      Horseshoe Mountain        Skier
# 13            Uintas             Cherry Hill  Snowmobiler
# 14         Salt Lake  Francis Peak Ridgeline  Snowmobiler
# 15         Salt Lake          Grandview Peak  Snowmobiler
# 16         Salt Lake                 Meadows        Skier
# 17             Ogden            Hells Canyon        Skier
# 18            Uintas             Yamaha Hill  Snowmobiler
# 19             Logan              Logan Peak  Snowmobiler
# 20         Salt Lake     Snowbird Ski Resort        Skier
# 21            Uintas             Co-op Creek  Snowmobiler
# 22            Uintas              Super Bowl  Snowmobiler
# 23         Salt Lake      Canyons Ski Resort        Skier
# 24         Salt Lake           Gobblers Knob        Skier
# 25             Ogden            Hells Canyon        Skier
# 26            Uintas              Buck Basin  Snowmobiler
# 27              None         Signal Mountain  Snowmobiler
# 28         Salt Lake            Pioneer Peak  Snowboarder
# 29             Ogden           Taylor Canyon  Snowboarder
# ..               ...                     ...          ...
# 66         Salt Lake        Wolverine Cirque        Skier
# 67         Salt Lake               Pinecrest        Skier
# 68             Provo                Sundance        Skier
# 69         Salt Lake      Snowbird periphery        Skier
# 70              Moab              Gold Basin        Skier
# 71             Logan         Tony Grove Lake        Skier
# 72         Salt Lake           Figure 8 Hill        Skier
# 73         Salt Lake           Alta Ski Area        Hiker
# 74         Salt Lake           Alta Ski Area      Natural
# 75         Salt Lake           Brighton Hill  Snowboarder
# 76             Provo            Water Hollow        Skier
# 77         Salt Lake             Sunset Peak        Skier
# 78         Salt Lake    Park City Ski Resort        Skier
# 79             Ogden         Powder Mountain        Skier
# 80         Salt Lake         Little Superior        Skier
# 81         Salt Lake            Murdock Peak        Skier
# 82         Salt Lake             Porter Fork        Skier
# 83         Salt Lake          Doughnut Falls        Skier
# 84         Salt Lake         Evergreen Ridge        Skier
# 85         Salt Lake         Lake Desolation        Skier
# 86              None                  Helper      Natural
# 87         Salt Lake     Snowbird Ski Resort        Skier
# 88         Salt Lake           Alta Ski Area        Skier
# 89         Salt Lake      Canyons Ski Resort        Skier
# 90         Salt Lake          Peruvian Ridge        Skier
# 91             Provo             Rock Canyon      Natural
# 92         Salt Lake           Pharoahs Glen        Hiker
# 93         Salt Lake    Park City Ski Resort        Skier
# 94             Ogden           Taylor Canyon        Skier
# 95             Ogden               Snowbasin        Skier
#
#                                           url
# 0                           /avalanches/23779
# 1                           /avalanches/20973
# 2                           /avalanches/20327
# 3                           /avalanches/20275
# 4                           /avalanches/16589
# 5                           /avalanches/15884
# 6                           /avalanches/15096
# 7                           /avalanches/18257
# 8                           /avalanches/18180
# 9                           /avalanches/18157
# 10                          /avalanches/18137
# 11                          /avalanches/17964
# 12                          /avalanches/17867
# 13                          /avalanches/17486
# 14                          /avalanches/17407
# 15                          /avalanches/17049
# 16                          /avalanches/17030
# 17                          /avalanches/16995
# 18                          /avalanches/17461
# 19                          /avalanches/17459
# 20                          /avalanches/17456
# 21                          /avalanches/17454
# 22                          /avalanches/17453
# 23                          /avalanches/17452
# 24                          /avalanches/17448
# 25                          /avalanches/17447
# 26                          /avalanches/17445
# 27                          /avalanches/17446
# 28                          /avalanches/17442
# 29                          /avalanches/17441
# ..                                        ...
# 66                          /avalanches/21119
# 67                          /avalanches/21118
# 68                          /avalanches/21117
# 69                          /avalanches/21116
# 70                          /avalanches/21115
# 71                          /avalanches/21114
# 72                          /avalanches/21113
# 73                          /avalanches/24257
# 74                          /avalanches/21111
# 75                          /avalanches/21110
# 76                          /avalanches/21109
# 77                          /avalanches/20768
# 78                          /avalanches/20766
# 79                          /avalanches/20757
# 80                          /avalanches/20746
# 81                          /avalanches/20745
# 82                          /avalanches/20744
# 83                          /avalanches/20743
# 84                          /avalanches/20742
# 85                          /avalanches/20741
# 86                          /avalanches/20740
# 87                          /avalanches/20739
# 88         /avalanches/accident-alta-ski-area
# 89  /avalanches/accident-canyons-ski-resort-0
# 90        /avalanches/accident-peruvian-ridge
# 91           /avalanches/accident-rock-canyon
# 92                          /avalanches/18545
# 93  /avalanches/accident-park-city-ski-resort
# 94       /avalanches/accident-taylor-canyon-0
# 95             /avalanches/accident-snowbasin
#
# [96 rows x 7 columns]

# %%
def get_avalanche_detail(url, item):
    req = r.get(url + item['url'], headers=headers)
    data = req.text
    
    soup = BeautifulSoup(data)
    content = soup.find(id='content')
    field_divs = content.find_all(class_='field')
    for div in field_divs:
        key_elem = div.find(class_='field-label')
        if key_elem is None:
            continue
        key = ''.join(key_elem.stripped_strings)
        try:
            value_elem = div.find(class_='field-item')
            value = ''.join(value_elem.stripped_strings).\
              replace('\xa0', ' ') 
        except AttributeError:
            pass
        if key in item:
            continue
        item[key] = value
    return item

def get_avalanche_details(url, avs):
    res = []
    for item in avs:
        item = get_avalanche_detail(url, item)
        res.append(item)
    return res

# %%
# %%time
detail = get_avalanche_details(base, avs)
# Out:
# CPU times: user 5.87 s, sys: 197 ms, total: 6.07 s
# Wall time: 2min 9s
# /Users/matt/.pycast-env/lib/python3.4/site-packages/bs4/__init__.py:166: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("html.parser"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# To get rid of this warning, change this:
#
#  BeautifulSoup([your markup])
#
# to this:
#
#  BeautifulSoup([your markup], "html.parser")
#
#   markup_type=markup_type))

# %%
df = pd.read_csv('ava-raw.csv')
df.T
# Out:
#                                                                                 0   \
# Unnamed: 0                                                                       0
# Accident and Rescue Summary:     This excellent and complete accident report wa...
# Aspect:                                                                      North
# Avalanche Problem:                                                 Persistent Slab
# Avalanche Type:                                                          Soft Slab
# Buried - Fully:                                                                  1
# Buried - Partly:                                                               NaN
# Carried:                                                                         1
# Caught:                                                                          1
# Comments:                                                                      NaN
# Coordinates:                                                                   NaN
# Depth:                                                                        2.5'
# Elevation:                                                                    8700
# Injured:                                                                       NaN
# Killed:                                                                          1
# Location Name or Route:                                              Hell's Canyon
# Observation Date:                                         Wednesday, March 4, 2015
# Observer Name:                              Waikirt and Fletcher, Snowbasin Patrol
# Occurence Time:                                                            11:00am
# Occurrence Date:                                          Wednesday, March 4, 2015
# Region:                                                                    11:00am
# Slope Angle:                                                                    43
# Snow Profile Comments:                                                         NaN
# Terrain Summary:                         Thanks to KSL News for the aerial photos.
# Trigger:                                                               Snowboarder
# Trigger: additional info:                                Unintentionally Triggered
# Vertical:                                                                     1500
# Video:                                                                         NaN
# Weak Layer:                                                                 Facets
# Weather Conditions and History:                                                NaN
# Width:                                                                          70
# coordinates                                     41.215552643517, -111.873779284110
# killed                                                                           1
# occurrence-date                                                          03/4/2015
# region-forecaster                                                            Ogden
# region-forecaster-1                                                   Hells Canyon
# trigger                                                                Snowboarder
# url                                                              /avalanches/23779
#
#                                                                                 1   \
# Unnamed: 0                                                                       1
# Accident and Rescue Summary:     Ryan A. Noorda and his brother Kevin are out f...
# Aspect:                                                                      North
# Avalanche Problem:                                                       Deep Slab
# Avalanche Type:                                                          Hard Slab
# Buried - Fully:                                                                  1
# Buried - Partly:                                                               NaN
# Carried:                                                                         1
# Caught:                                                                          1
# Comments:                                                                      NaN
# Coordinates:                                                                   NaN
# Depth:                                                                          4'
# Elevation:                                                                   10200
# Injured:                                                                       NaN
# Killed:                                                                          1
# Location Name or Route:                                                  Gold Hill
# Observation Date:                                          Saturday, March 8, 2014
# Observer Name:                        Craig Gordon/Ted Scroggin/Trent Meisenheimer
# Occurence Time:                                                             5:00pm
# Occurrence Date:                                             Friday, March 7, 2014
# Region:                                                                     5:00pm
# Slope Angle:                                                                    39
# Snow Profile Comments:                                                         NaN
# Terrain Summary:                 Gold Hill is a quick jaunt for local riders st...
# Trigger:                                                               Snowmobiler
# Trigger: additional info:                                Unintentionally Triggered
# Vertical:                                                                      200
# Video:                                                                         NaN
# Weak Layer:                                                             Depth Hoar
# Weather Conditions and History:  While the western Uinta's received early snow,...
# Width:                                                                         200
# coordinates                                     40.812120000000, -110.906296000000
# killed                                                                           1
# occurrence-date                                                          03/7/2014
# region-forecaster                                                           Uintas
# region-forecaster-1                                                      Gold Hill
# trigger                                                                Snowmobiler
# url                                                              /avalanches/20973
#
#                                                                                 2   \
# Unnamed: 0                                                                       2
# Accident and Rescue Summary:     Media reports-http://www.4utah.com/story/d/sto...
# Aspect:                                                                  Northeast
# Avalanche Problem:                                                 Persistent Slab
# Avalanche Type:                                                          Hard Slab
# Buried - Fully:                                                                  1
# Buried - Partly:                                                               NaN
# Carried:                                                                         1
# Caught:                                                                          1
# Comments:                        This isn't big avalanche terrain. As a matter ...
# Coordinates:                                                                   NaN
# Depth:                                                                          4'
# Elevation:                                                                    9600
# Injured:                                                                       NaN
# Killed:                                                                          1
# Location Name or Route:                                 Left Fork Huntington Creek
# Observation Date:                                         Sunday, February 9, 2014
# Observer Name:                                                        Craig Gordon
# Occurence Time:                                                             5:00pm
# Occurrence Date:                                          Sunday, February 9, 2014
# Region:                                                                     5:00pm
# Slope Angle:                                                                    38
# Snow Profile Comments:                                                         NaN
# Terrain Summary:                 Not the typical big terrain that makes up much...
# Trigger:                                                               Snowmobiler
# Trigger: additional info:                                       Remotely Triggered
# Vertical:                                                                      175
# Video:                                                                         NaN
# Weak Layer:                                                                 Facets
# Weather Conditions and History:  The Manti-Skyline has just been on the souther...
# Width:                                                                         300
# coordinates                                     39.585986000000, -111.270003000000
# killed                                                                           1
# occurrence-date                                                          02/9/2014
# region-forecaster                                                          Skyline
# region-forecaster-1                                           Huntington Reservior
# trigger                                                                Snowmobiler
# url                                                              /avalanches/20327
#
#                                                                                 3   \
# Unnamed: 0                                                                       3
# Accident and Rescue Summary:     According to preliminary information, a group ...
# Aspect:                                                                  Northeast
# Avalanche Problem:                                                      Storm Slab
# Avalanche Type:                                                          Soft Slab
# Buried - Fully:                                                                  1
# Buried - Partly:                                                               NaN
# Carried:                                                                         1
# Caught:                                                                          1
# Comments:                        We have not talked with anyone that was presen...
# Coordinates:                                                                   NaN
# Depth:                                                                         18"
# Elevation:                                                                    6400
# Injured:                                                                       NaN
# Killed:                                                                          1
# Location Name or Route:                                 Near Tibble Fork Reservoir
# Observation Date:                                       Saturday, February 8, 2014
# Observer Name:                                                  Kobernik - Tremper
# Occurence Time:                                                                NaN
# Occurrence Date:                                        Saturday, February 8, 2014
# Region:                                                 Saturday, February 8, 2014
# Slope Angle:                                                                   NaN
# Snow Profile Comments:                                                         NaN
# Terrain Summary:                 It was a steep gully with a stream at the bott...
# Trigger:                                                                 Snowshoer
# Trigger: additional info:                                Unintentionally Triggered
# Vertical:                                                                      125
# Video:                                                                         NaN
# Weak Layer:                                            New Snow/Old Snow Interface
# Weather Conditions and History:  The largest snow storm of the winter deposited...
# Width:                                                                         250
# coordinates                                     40.482366000000, -111.648088000000
# killed                                                                           1
# occurrence-date                                                          02/8/2014
# region-forecaster                                                            Provo
# region-forecaster-1                                                    Tibble Fork
# trigger                                                                  Snowshoer
# url                                                              /avalanches/20275
#
#                                                                                 4   \
# Unnamed: 0                                                                       4
# Accident and Rescue Summary:     This is a preliminary avalanche accident repor...
# Aspect:                                                                       East
# Avalanche Problem:                                                       Wind Slab
# Avalanche Type:                                                          Soft Slab
# Buried - Fully:                                                                NaN
# Buried - Partly:                                                               NaN
# Carried:                                                                         1
# Caught:                                                                          1
# Comments:                        After seeing the accident site and the avalanc...
# Coordinates:                                                                   NaN
# Depth:                                                                          8"
# Elevation:                                                                    9900
# Injured:                                                                       NaN
# Killed:                                                                          1
# Location Name or Route:                               Kessler Peak - Kessler Slabs
# Observation Date:                                           Friday, April 12, 2013
# Observer Name:                               Bruce Tremper, Hardesty, Meisenheimer
# Occurence Time:                                                             1:30pm
# Occurrence Date:                                          Thursday, April 11, 2013
# Region:                                                                     1:30pm
# Slope Angle:                                                                    45
# Snow Profile Comments:           Most of slope avalanched so there was not much...
# Terrain Summary:                 The slope where the avalanche occurred was ver...
# Trigger:                                                                     Skier
# Trigger: additional info:                                                      NaN
# Vertical:                                                                     1500
# Video:                                                                         NaN
# Weak Layer:                                            New Snow/Old Snow Interface
# Weather Conditions and History:  I will fill in the details here later, but bas...
# Width:                                                                          45
# coordinates                                     40.629000000000, -111.666412000000
# killed                                                                           1
# occurrence-date                                                         04/11/2013
# region-forecaster                                                        Salt Lake
# region-forecaster-1                                                  Kessler Slabs
# trigger                                                                      Skier
# url                                                              /avalanches/16589
#
#                                                                                 5   \
# Unnamed: 0                                                                       5
# Accident and Rescue Summary:     We have not spoken with anyone who was involve...
# Aspect:                                                                  Northeast
# Avalanche Problem:                                                 Persistent Slab
# Avalanche Type:                                                          Soft Slab
# Buried - Fully:                                                                  1
# Buried - Partly:                                                               NaN
# Carried:                                                                         1
# Caught:                                                                          1
# Comments:                        FORECASTER COMMENTS:It is not uncommon for gro...
# Coordinates:                                                                   NaN
# Depth:                                                                          2'
# Elevation:                                                                   10400
# Injured:                                                                       NaN
# Killed:                                                                          1
# Location Name or Route:          Southern end of the Manti Skyline just east ou...
# Observation Date:                                            Friday, March 1, 2013
# Observer Name:                                                            Kobernik
# Occurence Time:                                                                NaN
# Occurrence Date:                                             Friday, March 1, 2013
# Region:                                                      Friday, March 1, 2013
# Slope Angle:                                                                    38
# Snow Profile Comments:                                                         NaN
# Terrain Summary:                 The slope was an average of 38 degrees in stee...
# Trigger:                                                               Snowmobiler
# Trigger: additional info:                                                      NaN
# Vertical:                                                                      250
# Video:                                                                         NaN
# Weak Layer:                                                                 Facets
# Weather Conditions and History:  The snowpack in the southern part of the Manti...
# Width:                                                                         350
# coordinates                                     39.043600000000, -111.519000000000
# killed                                                                           1
# occurrence-date                                                          03/1/2013
# region-forecaster                                                          Skyline
# region-forecaster-1                                                 White Mountain
# trigger                                                                Snowmobiler
# url                                                              /avalanches/15884
#
#                                                                                 6   \
# Unnamed: 0                                                                       6
# Accident and Rescue Summary:     This is a preliminary accident report and we w...
# Aspect:                                                                  Southeast
# Avalanche Problem:                                                 Persistent Slab
# Avalanche Type:                                                          Hard Slab
# Buried - Fully:                                                                  2
# Buried - Partly:                                                               NaN
# Carried:                                                                         2
# Caught:                                                                          3
# Comments:                        The Utah Avalanche Center updates the western ...
# Coordinates:                                                                   NaN
# Depth:                                                                          3'
# Elevation:                                                                    8500
# Injured:                                                                       NaN
# Killed:                                                                          2
# Location Name or Route:                                  West Fork of the Duchesne
# Observation Date:                                       Saturday, January 19, 2013
# Observer Name:                                     Craig Gordon/Trent Meisenheimer
# Occurence Time:                                                             3:30pm
# Occurrence Date:                                          Friday, January 18, 2013
# Region:                                                                     3:30pm
# Slope Angle:                                                                    36
# Snow Profile Comments:           This micro climate produced very weak snow nea...
# Terrain Summary:                 Short and moderately steep, this isn't a big, ...
# Trigger:                                                               Snowmobiler
# Trigger: additional info:                                Unintentionally Triggered
# Vertical:                                                                       50
# Video:                                                                         NaN
# Weak Layer:                                                             Depth Hoar
# Weather Conditions and History:  The western Uinta snowpack is about as Contine...
# Width:                                                                         150
# coordinates                                                                    NaN
# killed                                                                           2
# occurrence-date                                                         01/18/2013
# region-forecaster                                                           Uintas
# region-forecaster-1                                          West Fork of Duchesne
# trigger                                                                Snowmobiler
# url                                                              /avalanches/15096
#
#                                                                                 7   \
# Unnamed: 0                                                                       7
# Accident and Rescue Summary:     The following link gives good information from...
# Aspect:                                                                  Southeast
# Avalanche Problem:                                                             NaN
# Avalanche Type:                                                          Soft Slab
# Buried - Fully:                                                                  1
# Buried - Partly:                                                               NaN
# Carried:                                                                         1
# Caught:                                                                          1
# Comments:                        Our thoughts go out to the friends and family ...
# Coordinates:                                                                   NaN
# Depth:                                                                          2'
# Elevation:                                                                   10200
# Injured:                                                                       NaN
# Killed:                                                                          1
# Location Name or Route:                   Beaver Basin, La Sal Mountains near Moab
# Observation Date:                                            Sunday, March 4, 2012
# Observer Name:                                                        Max Forgensi
# Occurence Time:                                                            Morning
# Occurrence Date:                                           Saturday, March 3, 2012
# Region:                                                                    Morning
# Slope Angle:                                                                    10
# Snow Profile Comments:                                                         NaN
# Terrain Summary:                                                               NaN
# Trigger:                                                               Snowmobiler
# Trigger: additional info:                                Unintentionally Triggered
# Vertical:                                                                     1000
# Video:                                                                         NaN
# Weak Layer:                                                                    NaN
# Weather Conditions and History:                                                NaN
# Width:                                                                         700
# coordinates                                     38.539320000000, -109.209852000000
# killed                                                                           1
# occurrence-date                                                          03/3/2012
# region-forecaster                                                             Moab
# region-forecaster-1                                                   Beaver Basin
# trigger                                                                Snowmobiler
# url                                                              /avalanches/18257
#
#                                                                                 8   \
# Unnamed: 0                                                                       8
# Accident and Rescue Summary:     Timothy Robert Baker, 24, died in an avalanche...
# Aspect:                                                                       East
# Avalanche Problem:                                                             NaN
# Avalanche Type:                                                          Soft Slab
# Buried - Fully:                                                                  1
# Buried - Partly:                                                               NaN
# Carried:                                                                         1
# Caught:                                                                          1
# Comments:                        This accident happened in Forest Service backc...
# Coordinates:                                                                   NaN
# Depth:                                                                         16"
# Elevation:                                                                    9800
# Injured:                                                                       NaN
# Killed:                                                                          1
# Location Name or Route:                                                 Dutch Draw
# Observation Date:                                      Thursday, February 23, 2012
# Observer Name:                                                        Evelyn/Brett
# Occurence Time:                                                             3:00pm
# Occurrence Date:                                       Thursday, February 23, 2012
# Region:                                                                     3:00pm
# Slope Angle:                                                                    40
# Snow Profile Comments:                                                         NaN
# Terrain Summary:                                                               NaN
# Trigger:                                                               Snowboarder
# Trigger: additional info:                                Unintentionally Triggered
# Vertical:                                                                      600
# Video:                                                                         NaN
# Weak Layer:                                                                 Facets
# Weather Conditions and History:                                                NaN
# Width:                                                                          50
# coordinates                                     40.653034000000, -111.592255000000
# killed                                                                           1
# occurrence-date                                                         02/23/2012
# region-forecaster                                                        Salt Lake
# region-forecaster-1                                                     Dutch Draw
# trigger                                                                Snowboarder
# url                                                              /avalanches/18180
#
#                                                                                 9   \
# Unnamed: 0                                                                       9
# Accident and Rescue Summary:     Four snowmobile riders were out for a day of s...
# Aspect:                                                                      North
# Avalanche Problem:                                                             NaN
# Avalanche Type:                                                          Hard Slab
# Buried - Fully:                                                                  1
# Buried - Partly:                                                               NaN
# Carried:                                                                         1
# Caught:                                                                          2
# Comments:                        Comments:  Rider B is very perplexed as to why...
# Coordinates:                                                                   NaN
# Depth:                                                                          3'
# Elevation:                                                                    9800
# Injured:                                                                       NaN
# Killed:                                                                          1
# Location Name or Route:                               West of Lost Creek Reservoir
# Observation Date:                                         Sunday, February 5, 2012
# Observer Name:                                   Kobernik, Meisenheimer, Rasmussen
# Occurence Time:                                                             5:00pm
# Occurrence Date:                                          Sunday, February 5, 2012
# Region:                                                                     5:00pm
# Slope Angle:                                                                    36
# Snow Profile Comments:                                                         NaN
# Terrain Summary:                                                               NaN
# Trigger:                                                               Snowmobiler
# Trigger: additional info:                                Unintentionally Triggered
# Vertical:                                                                      350
# Video:                                                                         NaN
# Weak Layer:                                                                 Facets
# Weather Conditions and History:                                                NaN
# Width:                                                                    1/4 mile
# coordinates                                     38.716456000000, -111.721988000000
# killed                                                                           1
# occurrence-date                                                          02/5/2012
# region-forecaster                                                          Skyline
# region-forecaster-1                                           Lost Creek Reservoir
# trigger                                                                Snowmobiler
# url                                                              /avalanches/18157
#
#                                                        ...                          \
# Unnamed: 0                                             ...
# Accident and Rescue Summary:                           ...
# Aspect:                                                ...
# Avalanche Problem:                                     ...
# Avalanche Type:                                        ...
# Buried - Fully:                                        ...
# Buried - Partly:                                       ...
# Carried:                                               ...
# Caught:                                                ...
# Comments:                                              ...
# Coordinates:                                           ...
# Depth:                                                 ...
# Elevation:                                             ...
# Injured:                                               ...
# Killed:                                                ...
# Location Name or Route:                                ...
# Observation Date:                                      ...
# Observer Name:                                         ...
# Occurence Time:                                        ...
# Occurrence Date:                                       ...
# Region:                                                ...
# Slope Angle:                                           ...
# Snow Profile Comments:                                 ...
# Terrain Summary:                                       ...
# Trigger:                                               ...
# Trigger: additional info:                              ...
# Vertical:                                              ...
# Video:                                                 ...
# Weak Layer:                                            ...
# Weather Conditions and History:                        ...
# Width:                                                 ...
# coordinates                                            ...
# killed                                                 ...
# occurrence-date                                        ...
# region-forecaster                                      ...
# region-forecaster-1                                    ...
# trigger                                                ...
# url                                                    ...
#
#                                                                                 86  \
# Unnamed: 0                                                                      86
# Accident and Rescue Summary:     Below is a narrative of the accident from The ...
# Aspect:                                                                        NaN
# Avalanche Problem:                                                             NaN
# Avalanche Type:                                                                NaN
# Buried - Fully:                                                                  1
# Buried - Partly:                                                               NaN
# Carried:                                                                         7
# Caught:                                                                          7
# Comments:                                                                      NaN
# Coordinates:                                                                   NaN
# Depth:                                                                          3'
# Elevation:                                                                     NaN
# Injured:                                                                       NaN
# Killed:                                                                          1
# Location Name or Route:               Braztah #6 Mine, Spring Creek west of Helper
# Observation Date:                                        Monday, February 24, 2014
# Observer Name:                                                  The Snowy Torrents
# Occurence Time:                                                             2:30pm
# Occurrence Date:                                          Friday, January 19, 1979
# Region:                                                                     2:30pm
# Slope Angle:                                                                    37
# Snow Profile Comments:                                                         NaN
# Terrain Summary:                                                               NaN
# Trigger:                                                                   Natural
# Trigger: additional info:                                                      NaN
# Vertical:                                                                      250
# Video:                                                                         NaN
# Weak Layer:                                                                 Facets
# Weather Conditions and History:                                                NaN
# Width:                                                                          60
# coordinates                                     39.702192039624, -110.949728952290
# killed                                                                           1
# occurrence-date                                                         01/19/1979
# region-forecaster                                                             None
# region-forecaster-1                                                         Helper
# trigger                                                                    Natural
# url                                                              /avalanches/20740
#
#                                                                                 87  \
# Unnamed: 0                                                                      87
# Accident and Rescue Summary:     Below is a narrative of the accident from The ...
# Aspect:                                                                       West
# Avalanche Problem:                                                 Persistent Slab
# Avalanche Type:                                                          Hard Slab
# Buried - Fully:                                                                  1
# Buried - Partly:                                                                 1
# Carried:                                                                         2
# Caught:                                                                          2
# Comments:                                                                      NaN
# Coordinates:                                                                   NaN
# Depth:                                                                          4'
# Elevation:                                                                    9700
# Injured:                                                                       NaN
# Killed:                                                                          1
# Location Name or Route:                                                 Gad Valley
# Observation Date:                                        Monday, February 24, 2014
# Observer Name:                                                  The Snowy Torrents
# Occurence Time:                                                             1:00pm
# Occurrence Date:                                           Thursday, March 3, 1977
# Region:                                                                     1:00pm
# Slope Angle:                                                                    34
# Snow Profile Comments:                                                         NaN
# Terrain Summary:                                                               NaN
# Trigger:                                                                     Skier
# Trigger: additional info:                                Unintentionally Triggered
# Vertical:                                                                      500
# Video:                                                                         NaN
# Weak Layer:                                                                 Facets
# Weather Conditions and History:                                                NaN
# Width:                                                                          80
# coordinates                                     40.564342704045, -111.652085678840
# killed                                                                           1
# occurrence-date                                                          03/3/1977
# region-forecaster                                                        Salt Lake
# region-forecaster-1                                            Snowbird Ski Resort
# trigger                                                                      Skier
# url                                                              /avalanches/20739
#
#                                                                                 88  \
# Unnamed: 0                                                                      88
# Accident and Rescue Summary:     Below is a narrative of the accident from The ...
# Aspect:                                                                      North
# Avalanche Problem:                                                      Storm Slab
# Avalanche Type:                                                          Soft Slab
# Buried - Fully:                                                                  1
# Buried - Partly:                                                               NaN
# Carried:                                                                         1
# Caught:                                                                          1
# Comments:                                                                      NaN
# Coordinates:                                                                   NaN
# Depth:                                                                          2'
# Elevation:                                                                    8900
# Injured:                                                                       NaN
# Killed:                                                                          1
# Location Name or Route:                                                  Snake Pit
# Observation Date:                                       Thursday, October 24, 2013
# Observer Name:                                                  The Snowy Torrents
# Occurence Time:                                                             3:30pm
# Occurrence Date:                                          Tuesday, January 6, 1976
# Region:                                                                     3:30pm
# Slope Angle:                                                                   NaN
# Snow Profile Comments:                                                         NaN
# Terrain Summary:                                                               NaN
# Trigger:                                                                     Skier
# Trigger: additional info:                                                      NaN
# Vertical:                                                                      100
# Video:                                                                         NaN
# Weak Layer:                                                                    NaN
# Weather Conditions and History:                                                NaN
# Width:                                                                         NaN
# coordinates                                     40.586506674316, -111.626428069460
# killed                                                                           1
# occurrence-date                                                          01/6/1976
# region-forecaster                                                        Salt Lake
# region-forecaster-1                                                  Alta Ski Area
# trigger                                                                      Skier
# url                                             /avalanches/accident-alta-ski-area
#
#                                                                                 89  \
# Unnamed: 0                                                                      89
# Accident and Rescue Summary:     Below is a narrative of the accident from The ...
# Aspect:                                                                        NaN
# Avalanche Problem:                                                        Wet Slab
# Avalanche Type:                                                                NaN
# Buried - Fully:                                                                  1
# Buried - Partly:                                                                 1
# Carried:                                                                         2
# Caught:                                                                          2
# Comments:                                                                      NaN
# ...
# Caught:                                                                          2
# Comments:                                                                      NaN
# Coordinates:                                                                   NaN
# Depth:                                                                         NaN
# Elevation:                                                                     NaN
# Injured:                                                                       NaN
# Killed:                                                                          1
# Location Name or Route:                                          Lower Rock Canyon
# Observation Date:                                       Tuesday, November 12, 2013
# Observer Name:                                                  The Snowy Torrents
# Occurence Time:                                                             8:30pm
# Occurrence Date:                                         Monday, February 19, 1968
# Region:                                                                     8:30pm
# Slope Angle:                                                                   NaN
# Snow Profile Comments:                                                         NaN
# Terrain Summary:                                                               NaN
# Trigger:                                                                   Natural
# Trigger: additional info:                                                      NaN
# Vertical:                                                                      NaN
# Video:                                                                         NaN
# Weak Layer:                                                                    NaN
# Weather Conditions and History:                                                NaN
# Width:                                                                         NaN
# coordinates                                     40.226133346151, -111.614400373680
# killed                                                                           1
# occurrence-date                                                         02/19/1968
# region-forecaster                                                            Provo
# region-forecaster-1                                                    Rock Canyon
# trigger                                                                    Natural
# url                                               /avalanches/accident-rock-canyon
#
#                                                                                 92  \
# Unnamed: 0                                                                      92
# Accident and Rescue Summary:     Below is a narrative of the accident from The ...
# Aspect:                                                                      North
# Avalanche Problem:                                                             NaN
# Avalanche Type:                                                          Soft Slab
# Buried - Fully:                                                                  1
# Buried - Partly:                                                                 1
# Carried:                                                                         2
# Caught:                                                                          2
# Comments:                                                                      NaN
# Coordinates:                                                                   NaN
# Depth:                                                                          4"
# Elevation:                                                                    8100
# Injured:                                                                       NaN
# Killed:                                                                          2
# Location Name or Route:                                              Pharoahs Glen
# Observation Date:                                       Tuesday, November 12, 2013
# Observer Name:                                                  The Snowy Torrents
# Occurence Time:                                                            11:30am
# Occurrence Date:                                         Sunday, February 12, 1967
# Region:                                                                    11:30am
# Slope Angle:                                                                    33
# Snow Profile Comments:                                                         NaN
# Terrain Summary:                                                               NaN
# Trigger:                                                                     Hiker
# Trigger: additional info:                                                      NaN
# Vertical:                                                                     1500
# Video:                                                                         NaN
# Weak Layer:                                                                Graupel
# Weather Conditions and History:                                                NaN
# Width:                                                                         300
# coordinates                                     40.708361000000, -111.759796000000
# killed                                                                           2
# occurrence-date                                                         02/12/1967
# region-forecaster                                                        Salt Lake
# region-forecaster-1                                                  Pharoahs Glen
# trigger                                                                      Hiker
# url                                                              /avalanches/18545
#
#                                                                                 93  \
# Unnamed: 0                                                                      93
# Accident and Rescue Summary:     Below is a narrative of the accident from The ...
# Aspect:                                                                       East
# Avalanche Problem:                                                             NaN
# Avalanche Type:                                                          Soft Slab
# Buried - Fully:                                                                  2
# Buried - Partly:                                                                 1
# Carried:                                                                         3
# Caught:                                                                          3
# Comments:                                                                      NaN
# Coordinates:                                                                   NaN
# Depth:                                                                         NaN
# Elevation:                                                                    8500
# Injured:                                                                       NaN
# Killed:                                                                          1
# Location Name or Route:                                   North of Bonanza ski run
# Observation Date:                                         Monday, October 14, 2013
# Observer Name:                                                  The Snowy Torrents
# Occurence Time:                                                             3:30pm
# Occurrence Date:                                         Friday, December 31, 1965
# Region:                                                                     3:30pm
# Slope Angle:                                                                   NaN
# Snow Profile Comments:                                                         NaN
# Terrain Summary:                                                               NaN
# Trigger:                                                                     Skier
# Trigger: additional info:                                                      NaN
# Vertical:                                                                      300
# Video:                                                                         NaN
# Weak Layer:                                                                    NaN
# Weather Conditions and History:                                                NaN
# Width:                                                                         NaN
# coordinates                                     40.631302096436, -111.516682134840
# killed                                                                           1
# occurrence-date                                                         12/31/1965
# region-forecaster                                                        Salt Lake
# region-forecaster-1                                           Park City Ski Resort
# trigger                                                                      Skier
# url                                      /avalanches/accident-park-city-ski-resort
#
#                                                                                 94  \
# Unnamed: 0                                                                      94
# Accident and Rescue Summary:     Below is a narrative of the accident from The ...
# Aspect:                                                                      North
# Avalanche Problem:                                                             NaN
# Avalanche Type:                                                                NaN
# Buried - Fully:                                                                  1
# Buried - Partly:                                                               NaN
# Carried:                                                                         3
# Caught:                                                                          3
# Comments:                                                                      NaN
# Coordinates:                                                                   NaN
# Depth:                                                                          3'
# Elevation:                                                                     NaN
# Injured:                                                                       NaN
# Killed:                                                                          1
# Location Name or Route:                                              Taylor Canyon
# Observation Date:                                         Monday, October 14, 2013
# Observer Name:                                                  The Snowy Torrents
# Occurence Time:                                                             4:00pm
# Occurrence Date:                                            Sunday, March 29, 1964
# Region:                                                                     4:00pm
# Slope Angle:                                                                   NaN
# Snow Profile Comments:                                                         NaN
# Terrain Summary:                                                               NaN
# Trigger:                                                                     Skier
# Trigger: additional info:                                                      NaN
# Vertical:                                                                     1250
# Video:                                                                         NaN
# Weak Layer:                                                                    NaN
# Weather Conditions and History:                                                NaN
# Width:                                                                         NaN
# coordinates                                     41.204951129311, -111.900259481650
# killed                                                                           1
# occurrence-date                                                         03/29/1964
# region-forecaster                                                            Ogden
# region-forecaster-1                                                  Taylor Canyon
# trigger                                                                      Skier
# url                                           /avalanches/accident-taylor-canyon-0
#
#                                                                                 95
# Unnamed: 0                                                                      95
# Accident and Rescue Summary:     Below is a narrative of the accident from The ...
# Aspect:                                                                        NaN
# Avalanche Problem:                                                             NaN
# Avalanche Type:                                                          Soft Slab
# Buried - Fully:                                                                NaN
# Buried - Partly:                                                               NaN
# Carried:                                                                       NaN
# Caught:                                                                          1
# Comments:                                                                      NaN
# Coordinates:                                                                   NaN
# Depth:                                                                         NaN
# Elevation:                                                                     NaN
# Injured:                                                                       NaN
# Killed:                                                                          1
# Location Name or Route:                                      John Paul Jones ridge
# Observation Date:                                       Thursday, October 10, 2013
# Observer Name:                                                  The Snowy Torrents
# Occurence Time:                                                             1:00pm
# Occurrence Date:                                             Sunday, March 9, 1958
# Region:                                                                     1:00pm
# Slope Angle:                                                                   NaN
# Snow Profile Comments:                                                         NaN
# Terrain Summary:                                                               NaN
# Trigger:                                                                     Skier
# Trigger: additional info:                                                      NaN
# Vertical:                                                                     1250
# Video:                                                                         NaN
# Weak Layer:                                                                    NaN
# Weather Conditions and History:                                                NaN
# Width:                                                                         NaN
# coordinates                                     41.205508551921, -111.875901000480
# killed                                                                           1
# occurrence-date                                                          03/9/1958
# region-forecaster                                                            Ogden
# region-forecaster-1                                                      Snowbasin
# trigger                                                                      Skier
# url                                                 /avalanches/accident-snowbasin
#
# [38 rows x 96 columns]
