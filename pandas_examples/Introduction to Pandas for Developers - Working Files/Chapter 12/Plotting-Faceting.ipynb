# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../beatles.csv', index_col=0)

# %%
df
# Out:
#                                    Title    Released  \
# 0                    Yesterday and Today  1966-06-15
# 1                               Revolver  1966-08-05
# 2                               Revolver  1966-08-08
# 3  Sgt. Pepper's Lonely Hearts Club Band  1967-06-01
# 4                   Magical Mystery Tour  1967-11-27
# 5                            The Beatles  1968-11-22
# 6                       Yellow Submarine  1969-01-13
# 7                             Abbey Road  1969-09-26
# 8                              Let It Be  1970-05-08
#
#                           Label  UK Chart Position  US Chart Position  \
# 0                   Capitol(US)                NaN                  1
# 1                Parlophone(UK)                  1                NaN
# 2                Capitol(US)[C]                NaN                  1
# 3   Parlophone(UK), Capitol(US)                  1                  1
# 4   Parlophone(UK), Capitol(US)                NaN                  1
# 5        Apple(UK), Capitol(US)                  1                  1
# 6        Apple(UK), Capitol(US)                  3                  2
# 7        Apple(UK), Capitol(US)                  1                  1
# 8  Apple(UK),United Artists(US)                  1                  1
#
#   BPI Certification RIAA Certification  Count Songs  Year
# 0               NaN         2xPlatinum           11  1966
# 1          Platinum                NaN           14  1966
# 2               NaN         5xPlatinum           14  1966
# 3        3xPlatinum        11xPlatinum           13  1967
# 4          Platinum         6xPlatinum           11  1967
# 5          Platinum        19xPlatinum           30  1968
# 6            Silver           Platinum            6  1969
# 7        2xPlatinum        12xPlatinum           17  1969
# 8              Gold         4xPlatinum           12  1970

# %% [markdown]
# ## Faceting

# %%
df.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x10c35b128>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10c3b0550>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x10c3f7c18>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10c446630>]], dtype=object)

# %%
df.hist()
plt.tight_layout()

# %%
df.boxplot()
# Out:
# /Users/matt/.env/pycast-env/lib/python3.5/site-packages/ipykernel/__main__.py:1: FutureWarning:
# The default value for 'return_type' will change to 'axes' in a future release.
#  To use the future behavior now, set return_type='axes'.
#  To keep the previous behavior and silence this warning, set return_type='dict'.
#   if __name__ == '__main__':
# {'boxes': [<matplotlib.lines.Line2D at 0x10c9013c8>,
#   <matplotlib.lines.Line2D at 0x10c916828>,
#   <matplotlib.lines.Line2D at 0x10c92e198>,
#   <matplotlib.lines.Line2D at 0x10c978ac8>],
#  'caps': [<matplotlib.lines.Line2D at 0x10c90ce48>,
#   <matplotlib.lines.Line2D at 0x10c90cf60>,
#   <matplotlib.lines.Line2D at 0x10c9227b8>,
#   <matplotlib.lines.Line2D at 0x10c922fd0>,
#   <matplotlib.lines.Line2D at 0x10c9339e8>,
#   <matplotlib.lines.Line2D at 0x10c973940>,
#   <matplotlib.lines.Line2D at 0x10c984a58>,
#   <matplotlib.lines.Line2D at 0x10c984b70>],
#  'fliers': [<matplotlib.lines.Line2D at 0x10c912fd0>,
#   <matplotlib.lines.Line2D at 0x10c928f60>,
#   <matplotlib.lines.Line2D at 0x10c9789b0>,
#   <matplotlib.lines.Line2D at 0x10c98abe0>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x10c9127b8>,
#   <matplotlib.lines.Line2D at 0x10c928128>,
#   <matplotlib.lines.Line2D at 0x10c973a58>,
#   <matplotlib.lines.Line2D at 0x10c98a3c8>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x10c901dd8>,
#   <matplotlib.lines.Line2D at 0x10c901ef0>,
#   <matplotlib.lines.Line2D at 0x10c916f98>,
#   <matplotlib.lines.Line2D at 0x10c91ef60>,
#   <matplotlib.lines.Line2D at 0x10c92ef98>,
#   <matplotlib.lines.Line2D at 0x10c9338d0>,
#   <matplotlib.lines.Line2D at 0x10c97f9e8>,
#   <matplotlib.lines.Line2D at 0x10c97fb00>]}

# %%
pos = [x for x in df.columns if 'Position' in x]
pos
# Out:
# ['UK Chart Position', 'US Chart Position']

# %%
df[pos].boxplot()
# Out:
# /Users/matt/.env/pycast-env/lib/python3.5/site-packages/ipykernel/__main__.py:1: FutureWarning:
# The default value for 'return_type' will change to 'axes' in a future release.
#  To use the future behavior now, set return_type='axes'.
#  To keep the previous behavior and silence this warning, set return_type='dict'.
#   if __name__ == '__main__':
# {'boxes': [<matplotlib.lines.Line2D at 0x10ca8ebe0>,
#   <matplotlib.lines.Line2D at 0x10ca9ffd0>],
#  'caps': [<matplotlib.lines.Line2D at 0x10ca94f60>,
#   <matplotlib.lines.Line2D at 0x10ca99eb8>,
#   <matplotlib.lines.Line2D at 0x10caaafd0>,
#   <matplotlib.lines.Line2D at 0x10cab1828>],
#  'fliers': [<matplotlib.lines.Line2D at 0x10ca9ff28>,
#   <matplotlib.lines.Line2D at 0x10cab5898>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x10ca99fd0>,
#   <matplotlib.lines.Line2D at 0x10cab1940>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x10ca8eda0>,
#   <matplotlib.lines.Line2D at 0x10ca94e48>,
#   <matplotlib.lines.Line2D at 0x10caa5f60>,
#   <matplotlib.lines.Line2D at 0x10caaa7b8>]}

# %%
df[pos].describe()
# Out:
#        UK Chart Position  US Chart Position
# count           6.000000           8.000000
# mean            1.333333           1.125000
# std             0.816497           0.353553
# min             1.000000           1.000000
# 25%             1.000000           1.000000
# 50%             1.000000           1.000000
# 75%             1.000000           1.000000
# max             3.000000           2.000000

# %%
df.boxplot(by='Year')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x10ca5f7b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10c7c0128>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x10c874b38>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10c61cb00>]], dtype=object)

# %%
from pandas.tools.plotting import scatter_matrix

# %%
scatter_matrix(df)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x10ca5bdd8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10cd84908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10cd8c710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10cdcd4e0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x10ce1d9b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10ce5f320>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10cea8080>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10cee7160>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x10cf32278>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10cf4ef28>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10cfbb1d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10d0046a0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x10d03fc18>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10d08f358>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10c572748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10d0f7668>]], dtype=object)

# %%
scatter_matrix(df)
plt.tight_layout()
